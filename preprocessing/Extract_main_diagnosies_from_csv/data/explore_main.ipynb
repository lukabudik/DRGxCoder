# %%
# Load the csv table
import pandas as pd
data = pd.read_csv('raw_csv_sheets/drg_diagnozy_main_raw.csv')
data
# Out:
# /var/folders/yp/grgl04_s0sj4d3kfplcrvf2m0000gn/T/ipykernel_22116/2268204029.py:3: DtypeWarning: Columns (2,13,14,15,16,17,18,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('raw_csv_sheets/drg_diagnozy_main_raw.csv')
#         Kod                                              Nazev  \
# 0       A00                                            Cholera
# 1      A000  Cholera‚ původce: Vibrio cholerae 01‚ biotyp c...
# 2      A001  Cholera‚ původce: Vibrio cholerae 01‚ biotyp e...
# 3      A009                                         Cholera NS
# 4       A01                           Břišní tyfus a paratyfus
# ...     ...                                                ...
# 38764  Z992                       Závislost na renální dialýze
# 38765  Z993                      Závislost na pojízdném křesle
# 38766  Z994                          Závislost na umělém srdci
# 38767  Z998  Závislost na jiných pomocných přístrojích a po...
# ...

# %%
#Create new column with only - Kod, Nazev, Kategorie columns
data_new = data[['Kod', 'Nazev', 'Kategorie']]
data_new
# Out:
#         Kod                                              Nazev  \
# 0       A00                                            Cholera
# 1      A000  Cholera‚ původce: Vibrio cholerae 01‚ biotyp c...
# 2      A001  Cholera‚ původce: Vibrio cholerae 01‚ biotyp e...
# 3      A009                                         Cholera NS
# 4       A01                           Břišní tyfus a paratyfus
# ...     ...                                                ...
# 38764  Z992                       Závislost na renální dialýze
# 38765  Z993                      Závislost na pojízdném křesle
# 38766  Z994                          Závislost na umělém srdci
# 38767  Z998  Závislost na jiných pomocných přístrojích a po...
# 38768  Z999  Závislost na neurčeném pomocném přístroji a po...
#
#                      Kategorie
# 0                          NaN
# 1      Střevní infekční nemoci
# 2      Střevní infekční nemoci
# 3      Střevní infekční nemoci
# 4                          NaN
# ...

# %%
# save the table as csv
data_new.to_csv('drg_diagnozy_main_extracted_filtered.csv', index=False)
