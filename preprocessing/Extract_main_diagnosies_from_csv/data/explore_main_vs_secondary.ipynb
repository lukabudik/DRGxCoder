# %%
# Load the csv table
import pandas as pd
data = pd.read_csv('raw_csv_sheets/main_vs_secondary.csv')
data
# Out:
#        Kod VDG                                          Nazev VDG Kod HDG  \
# 0         A000  Cholera, původce: Vibrio cholerae 01, biotyp c...    A000
# 1         A000  Cholera, původce: Vibrio cholerae 01, biotyp c...    A001
# 2         A001  Cholera, původce: Vibrio cholerae 01, biotyp e...    A001
# 3         A009                                         Cholera NS    A001
# 4         A010                                       Břišní tyfus    A001
# ...        ...                                                ...     ...
# 543897    N280                         Ischemie a infarkt ledviny    Z992
# 543898    N290                     Pozdní syfilis ledvin (A52.7+)    Z992
# 543899    N291  Jiné por. ledv. a močovodu při inf. a par. n. ...    Z992
# 543900    Z991                           Závislost na respirátoru    Z998
# 543901    Z991                           Závislost na respirátoru    Z999
#
#                                                 Nazev HDG  Zavaznost (zDG)
# ...

# %%
#Create new column with only - Kod, Nazev, Kategorie columns
data_new = data[['Kod VDG', 'Nazev VDG', 'Kod HDG', 'Nazev HDG']].copy()
data_new
# Out:
#        Kod VDG                                          Nazev VDG Kod HDG  \
# 0         A000  Cholera, původce: Vibrio cholerae 01, biotyp c...    A000
# 1         A000  Cholera, původce: Vibrio cholerae 01, biotyp c...    A001
# 2         A001  Cholera, původce: Vibrio cholerae 01, biotyp e...    A001
# 3         A009                                         Cholera NS    A001
# 4         A010                                       Břišní tyfus    A001
# ...        ...                                                ...     ...
# 543897    N280                         Ischemie a infarkt ledviny    Z992
# 543898    N290                     Pozdní syfilis ledvin (A52.7+)    Z992
# 543899    N291  Jiné por. ledv. a močovodu při inf. a par. n. ...    Z992
# 543900    Z991                           Závislost na respirátoru    Z998
# 543901    Z991                           Závislost na respirátoru    Z999
#
#                                                 Nazev HDG
# ...

# %%
# save the table as csv
data_new.to_csv('drg_diagnozy_main_vs_secondary_extracted_filtered.csv', index=False)
